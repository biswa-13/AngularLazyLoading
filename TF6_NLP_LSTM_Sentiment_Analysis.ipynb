# %% [markdown]
# <a href="https://colab.research.google.com/github/biswa-13/AngularLazyLoading/blob/master/TF6_NLP_LSTM_Sentiment_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This will demostrate the step by step procedure for implementing the NLP for SentimentnAnalysis using the LongShort Term Memory mechanism.<br/>
# Reference: https://colab.research.google.com/github/tensorflow/examples/blob/master/courses/udacity_intro_to_tensorflow_for_deep_learning/l10c02_nlp_multiple_models_for_predicting_sentiment.ipynb#scrollTo=3N6Zul47PMED
#
# https://classroom.udacity.com/courses/ud187/lessons/52b95146-ddb7-471c-9237-20fb24d25237/concepts/001cc073-b837-425d-98be-64c231a6eb9d

# %%
# - importing the required libraries

import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

print("Finish - importing the required libraries")

# %%
# - declaring the required variables

vaocab_len = 1000
max_len = 10
padding = "pre"
truncating = "pre"
embed_dim = 16
epochs = 200
dataset_name = 'glue/sst2'
oovToken = "<OOV>"
print("Finish - declaring the required variables")

# %%
# - load dataset 
dataset, dataset_info = tfds.load(dataset_name, with_info= True)
print("dataset_info -->",dataset_info)

print("Finish - load dataset")

# %%
# - Prapare the training and testing data
dataset_train, dataset_validation = dataset['train'], dataset['validation']
print("dataset_train info-->", dataset_train)
print("dataset_validation info-->", dataset_validation)
dataset_train_seneteces = []
dataset_train_labels = []
dataset_val_sentneces = []
dataset_val_labels = []

# we are going to take only the 10000 items from the dataset_train by using the take(10000)
for data in dataset_train.take(10000):
  text, label = data["sentence"], data["label"]
  dataset_train_seneteces.append(str(text.numpy()))
  dataset_train_labels.append(label.numpy())

print("dataset_train_seneteces length -->",len(dataset_train_seneteces), ", dataset_train_labels length -->", len(dataset_train_labels))

# we are going to take all the validation dataset by using the take(-1)
for val_data in dataset_validation.take(-1):
  val_text, val_label = val_data["sentence"], val_data["label"]
  dataset_val_sentneces.append(str(val_text.numpy()))
  dataset_val_labels.append(val_label.numpy())

print("dataset_val_sentneces length -->",len(dataset_val_sentneces), ", dataset_val_labels length -->", len(dataset_val_labels))

print("Finish - Prapare the training and testing data")

# %%
# - Tokenizing, Sequencing and Padding the train and validation dataset

# -- tokenizing the words
tokenizer = Tokenizer(num_words= vaocab_len, oov_token= oovToken)
tokenizer.fit_on_texts(dataset_train_seneteces)
word_index = tokenizer.word_index

# -- sequencing the words
dataset_train_sequence = tokenizer.texts_to_sequences(dataset_train_seneteces)
dataset_test_sequence = tokenizer.texts_to_sequences(dataset_val_sentneces)

dataset_train_padding =  pad_sequences(dataset_train_sequence, maxlen= max_len, padding= padding, truncating= truncating)
dataset_val_padding = pad_sequences(dataset_test_sequence, maxlen= max_len, padding= padding, truncating= truncating)

dataset_train_labels_final = np.array(dataset_train_labels)
dataset_val_labels_final = np.array(dataset_val_labels)

print("Finish - Tokenizing, Sequencing and Padding the train and validation dataset")

# %%
# - implemeting a generic function to plot the training graph of the models
def plot_graph(history, string):
   plt.plot(history.history[string])
   plt.plot(history.history["val_"+string])
   plt.xlabel("epochs")
   plt.ylabel(string)
   plt.legend([string, "val_"+string])
   plt.show()

print("Finish - implemeting a generic function to plot the training graph of the models")
# Out:
# Finish - implemeting a generic function to plot the training graph of the models

# %%
# - Creating and Training a model using the Embedding layer

# -- build the model
embed_sentiment_model = tf.keras.Sequential([
                             tf.keras.layers.Embedding(input_dim= vaocab_len, output_dim= embed_dim, input_length= max_len ),
                             tf.keras.layers.GlobalAveragePooling1D(),
                             tf.keras.layers.Dense(1, activation="sigmoid")
])

# -- compile the model
embed_sentiment_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])
embed_sentiment_model.summary()

embed_model_history =  embed_sentiment_model.fit(dataset_train_padding, dataset_train_labels_final, epochs= epochs, validation_data=(dataset_val_padding, dataset_val_labels_final))

embed_sentiment_model.save("embed_sentiment_model.h5")



print("Finish - Creating and Training  a model using the Embedding layer")

# %%
plot_graph(embed_model_history, "loss")
plot_graph(embed_model_history, "accuracy")

# %%
# - Creating and Training a model using the Embeding with Convolutional layer

# -- building the model
cnn_sentiment_model = tf.keras.Sequential([
                                           tf.keras.layers.Embedding(input_dim= vaocab_len, output_dim= embed_dim, input_length= max_len),
                                           tf.keras.layers.Conv1D(16,5, activation='relu'),
                                           tf.keras.layers.GlobalAveragePooling1D(),
                                           tf.keras.layers.Dense(1, activation='sigmoid')
])

# -- compiling the model
cnn_sentiment_model.compile(loss= "binary_crossentropy", optimizer='adam', metrics=['accuracy'])
cnn_sentiment_model.summary()

# -- training the model
cnn_model_history =  cnn_sentiment_model.fit(dataset_train_padding, dataset_train_labels_final, epochs= 10, validation_data=(dataset_val_padding, dataset_val_labels_final))

cnn_sentiment_model.save("cnn_sentiment_model.h5")



print("Finish - Creating and Training a model using the Embeding with Convolutional layer")
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 10, 16)            16000
# _________________________________________________________________
# conv1d (Conv1D)              (None, 6, 16)             1296
# _________________________________________________________________
# global_average_pooling1d_1 ( (None, 16)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 17,313
# Trainable params: 17,313
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 313/313 [==============================] - 1s 4ms/step - loss: 0.6581 - accuracy: 0.6074 - val_loss: 0.6060 - val_accuracy: 0.6823
# Epoch 2/10
# 313/313 [==============================] - 1s 4ms/step - loss: 0.5489 - accuracy: 0.7127 - val_loss: 0.6131 - val_accuracy: 0.6709
# Epoch 3/10
# 313/313 [==============================] - 1s 4ms/step - loss: 0.5078 - accuracy: 0.7360 - val_loss: 0.6320 - val_accuracy: 0.6858
# Epoch 4/10
# 313/313 [==============================] - 1s 4ms/step - loss: 0.4910 - accuracy: 0.7511 - val_loss: 0.6430 - val_accuracy: 0.6846
# Epoch 5/10
# 313/313 [==============================] - 1s 3ms/step - loss: 0.4806 - accuracy: 0.7557 - val_loss: 0.6612 - val_accuracy: 0.6709
# Epoch 6/10
# 313/313 [==============================] - 1s 3ms/step - loss: 0.4721 - accuracy: 0.7563 - val_loss: 0.6693 - val_accuracy: 0.6743
# Epoch 7/10
# 313/313 [==============================] - 1s 3ms/step - loss: 0.4630 - accuracy: 0.7614 - val_loss: 0.6780 - val_accuracy: 0.6766
# Epoch 8/10
# 313/313 [==============================] - 1s 3ms/step - loss: 0.4539 - accuracy: 0.7686 - val_loss: 0.6805 - val_accuracy: 0.6823
# Epoch 9/10
# 313/313 [==============================] - 1s 3ms/step - loss: 0.4432 - accuracy: 0.7728 - val_loss: 0.6893 - val_accuracy: 0.6755
# Epoch 10/10
# 313/313 [==============================] - 1s 3ms/step - loss: 0.4337 - accuracy: 0.7774 - val_loss: 0.7027 - val_accuracy: 0.6709
# Finish - Creating and Training a model using the Embeding with Convolutional layer

# %%
plot_graph(cnn_model_history, 'accuracy')
plot_graph(cnn_model_history, 'loss')

# %%
# - Creating and Training a model using the Embeding with GRU layer

# -- building the model

gru_sentiment_model = tf.keras.Sequential([
                                           tf.keras.layers.Embedding(input_dim= vaocab_len, output_dim= embed_dim, input_length= max_len),
                                           tf.keras.layers.Bidirectional(tf.keras.layers.GRU(32)),
                                           tf.keras.layers.Dense(1, activation='sigmoid')
])

learning_rate = 0.00003 # slower than the default learning rate
# -- compiling the model
gru_sentiment_model.compile(loss= "binary_crossentropy", optimizer= tf.keras.optimizers.Adam(learning_rate), metrics=['accuracy'])
gru_sentiment_model.summary

# -- trainging the model
gru_model_history = gru_sentiment_model.fit(dataset_train_padding, dataset_train_labels_final, epochs= 20, validation_data=(dataset_val_padding, dataset_val_labels_final))

gru_sentiment_model.save("gru_sentiment_model.h5")


print("Finish - Creating and Training a model using the Embeding with GRU layer")
# Out:
# Epoch 1/20
# 313/313 [==============================] - 2s 7ms/step - loss: 0.6911 - accuracy: 0.5424 - val_loss: 0.6932 - val_accuracy: 0.5092
# Epoch 2/20
# 313/313 [==============================] - 2s 6ms/step - loss: 0.6868 - accuracy: 0.5590 - val_loss: 0.6942 - val_accuracy: 0.5092
# Epoch 3/20
# 313/313 [==============================] - 2s 6ms/step - loss: 0.6845 - accuracy: 0.5590 - val_loss: 0.6952 - val_accuracy: 0.5092
# Epoch 4/20
# 313/313 [==============================] - 2s 6ms/step - loss: 0.6831 - accuracy: 0.5590 - val_loss: 0.6952 - val_accuracy: 0.5092
# Epoch 5/20
# 313/313 [==============================] - 2s 6ms/step - loss: 0.6818 - accuracy: 0.5590 - val_loss: 0.6947 - val_accuracy: 0.5092
# Epoch 6/20
# 313/313 [==============================] - 2s 6ms/step - loss: 0.6804 - accuracy: 0.5590 - val_loss: 0.6935 - val_accuracy: 0.5092
# Epoch 7/20
# 313/313 [==============================] - 2s 6ms/step - loss: 0.6785 - accuracy: 0.5592 - val_loss: 0.6919 - val_accuracy: 0.5103
# Epoch 8/20
# 313/313 [==============================] - 2s 6ms/step - loss: 0.6760 - accuracy: 0.5623 - val_loss: 0.6896 - val_accuracy: 0.5183
# Epoch 9/20
# 313/313 [==============================] - 2s 6ms/step - loss: 0.6727 - accuracy: 0.5717 - val_loss: 0.6862 - val_accuracy: 0.5344
# Epoch 10/20
# 313/313 [==============================] - 2s 6ms/step - loss: 0.6679 - accuracy: 0.5852 - val_loss: 0.6808 - val_accuracy: 0.5711
# Epoch 11/20
# 313/313 [==============================] - 2s 6ms/step - loss: 0.6612 - accuracy: 0.6049 - val_loss: 0.6734 - val_accuracy: 0.5975
# Epoch 12/20
# 313/313 [==============================] - 2s 6ms/step - loss: 0.6515 - accuracy: 0.6214 - val_loss: 0.6620 - val_accuracy: 0.6193
# Epoch 13/20
# 313/313 [==============================] - 2s 6ms/step - loss: 0.6372 - accuracy: 0.6337 - val_loss: 0.6465 - val_accuracy: 0.6365
# Epoch 14/20
# 313/313 [==============================] - 2s 6ms/step - loss: 0.6195 - accuracy: 0.6483 - val_loss: 0.6352 - val_accuracy: 0.6456
# Epoch 15/20
# 313/313 [==============================] - 2s 6ms/step - loss: 0.6053 - accuracy: 0.6614 - val_loss: 0.6306 - val_accuracy: 0.6560
# Epoch 16/20
# 313/313 [==============================] - 2s 6ms/step - loss: 0.5941 - accuracy: 0.6719 - val_loss: 0.6262 - val_accuracy: 0.6560
# Epoch 17/20
# 313/313 [==============================] - 2s 6ms/step - loss: 0.5835 - accuracy: 0.6813 - val_loss: 0.6244 - val_accuracy: 0.6606
# Epoch 18/20
# 313/313 [==============================] - 2s 6ms/step - loss: 0.5729 - accuracy: 0.6893 - val_loss: 0.6203 - val_accuracy: 0.6697
# Epoch 19/20
# 313/313 [==============================] - 2s 6ms/step - loss: 0.5614 - accuracy: 0.6984 - val_loss: 0.6178 - val_accuracy: 0.6755
# Epoch 20/20
# 313/313 [==============================] - 2s 6ms/step - loss: 0.5490 - accuracy: 0.7089 - val_loss: 0.6152 - val_accuracy: 0.6869
# Finish - Creating and Training a model using the Embeding with GRU layer

# %%
plot_graph(gru_model_history, 'accuracy')
plot_graph(gru_model_history, 'loss')

# %%
# - Creating and Training a model using the Embeding with LSTM layer

# -- building the model
lstm_sentiment_model = tf.keras.Sequential([
                                            tf.keras.layers.Embedding(input_dim= vaocab_len, output_dim= embed_dim, input_length= max_len),
                                            tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(embed_dim)), 
                                            tf.keras.layers.Dense(1, activation='sigmoid')
])

learning_rate = 0.00003 # slower than the default learning rate
# -- compiling the model
# lstm_sentiment_model.compile(loss= "binary_crossentropy", optimizer= tf.keras.optimizers.Adam(learning_rate), metrics=['accuracy'])
lstm_sentiment_model.compile(loss= "binary_crossentropy", optimizer= 'adam', metrics=['accuracy'])
lstm_sentiment_model.summary

# -- trainging the model
lstm_model_history = lstm_sentiment_model.fit(dataset_train_padding, dataset_train_labels_final, epochs= 80, validation_data=(dataset_val_padding, dataset_val_labels_final))

lstm_sentiment_model.save("lstm_sentiment_model.h5")


print("Finish - Creating and Training a model using the Embeding with LSTM layer")
# Out:
# Epoch 1/80
# 313/313 [==============================] - 3s 8ms/step - loss: 0.6428 - accuracy: 0.6114 - val_loss: 0.5815 - val_accuracy: 0.6961
# Epoch 2/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.5239 - accuracy: 0.7241 - val_loss: 0.6059 - val_accuracy: 0.6961
# Epoch 3/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.4958 - accuracy: 0.7389 - val_loss: 0.5983 - val_accuracy: 0.6835
# Epoch 4/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.4806 - accuracy: 0.7458 - val_loss: 0.6084 - val_accuracy: 0.6915
# Epoch 5/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.4665 - accuracy: 0.7524 - val_loss: 0.6043 - val_accuracy: 0.6927
# Epoch 6/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.4531 - accuracy: 0.7604 - val_loss: 0.6345 - val_accuracy: 0.6961
# Epoch 7/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.4360 - accuracy: 0.7697 - val_loss: 0.6820 - val_accuracy: 0.6835
# Epoch 8/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.4227 - accuracy: 0.7769 - val_loss: 0.7041 - val_accuracy: 0.6995
# Epoch 9/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.4074 - accuracy: 0.7829 - val_loss: 0.7516 - val_accuracy: 0.6961
# Epoch 10/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3990 - accuracy: 0.7889 - val_loss: 0.7616 - val_accuracy: 0.7064
# Epoch 11/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3874 - accuracy: 0.7892 - val_loss: 0.7874 - val_accuracy: 0.6915
# Epoch 12/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3811 - accuracy: 0.7930 - val_loss: 0.8299 - val_accuracy: 0.6961
# Epoch 13/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3698 - accuracy: 0.7945 - val_loss: 0.8574 - val_accuracy: 0.6858
# Epoch 14/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3601 - accuracy: 0.8024 - val_loss: 0.8857 - val_accuracy: 0.6881
# Epoch 15/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3558 - accuracy: 0.8007 - val_loss: 0.9458 - val_accuracy: 0.6950
# Epoch 16/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3476 - accuracy: 0.8036 - val_loss: 0.9719 - val_accuracy: 0.6915
# Epoch 17/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3426 - accuracy: 0.8085 - val_loss: 0.9886 - val_accuracy: 0.6789
# Epoch 18/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3331 - accuracy: 0.8126 - val_loss: 1.0542 - val_accuracy: 0.6674
# Epoch 19/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3239 - accuracy: 0.8128 - val_loss: 1.1436 - val_accuracy: 0.6640
# Epoch 20/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3202 - accuracy: 0.8165 - val_loss: 1.1685 - val_accuracy: 0.6651
# Epoch 21/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3133 - accuracy: 0.8213 - val_loss: 1.2288 - val_accuracy: 0.6537
# Epoch 22/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3055 - accuracy: 0.8246 - val_loss: 1.2644 - val_accuracy: 0.6560
# Epoch 23/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3043 - accuracy: 0.8296 - val_loss: 1.2967 - val_accuracy: 0.6537
# Epoch 24/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2904 - accuracy: 0.8349 - val_loss: 1.3137 - val_accuracy: 0.6514
# Epoch 25/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2831 - accuracy: 0.8377 - val_loss: 1.3956 - val_accuracy: 0.6560
# Epoch 26/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2824 - accuracy: 0.8405 - val_loss: 1.4079 - val_accuracy: 0.6537
# Epoch 27/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2775 - accuracy: 0.8441 - val_loss: 1.4798 - val_accuracy: 0.6468
# Epoch 28/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2668 - accuracy: 0.8505 - val_loss: 1.5230 - val_accuracy: 0.6537
# Epoch 29/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2663 - accuracy: 0.8513 - val_loss: 1.5056 - val_accuracy: 0.6583
# Epoch 30/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2625 - accuracy: 0.8531 - val_loss: 1.5447 - val_accuracy: 0.6571
# Epoch 31/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2616 - accuracy: 0.8523 - val_loss: 1.5675 - val_accuracy: 0.6674
# Epoch 32/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2522 - accuracy: 0.8581 - val_loss: 1.6863 - val_accuracy: 0.6571
# Epoch 33/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2457 - accuracy: 0.8628 - val_loss: 1.7071 - val_accuracy: 0.6537
# Epoch 34/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2440 - accuracy: 0.8645 - val_loss: 1.7031 - val_accuracy: 0.6514
# Epoch 35/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2440 - accuracy: 0.8633 - val_loss: 1.7430 - val_accuracy: 0.6548
# Epoch 36/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2365 - accuracy: 0.8667 - val_loss: 1.8428 - val_accuracy: 0.6479
# Epoch 37/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2321 - accuracy: 0.8702 - val_loss: 1.8689 - val_accuracy: 0.6399
# Epoch 38/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2304 - accuracy: 0.8696 - val_loss: 1.8740 - val_accuracy: 0.6433
# Epoch 39/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2254 - accuracy: 0.8726 - val_loss: 1.9130 - val_accuracy: 0.6606
# Epoch 40/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2252 - accuracy: 0.8755 - val_loss: 1.9607 - val_accuracy: 0.6674
# Epoch 41/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2192 - accuracy: 0.8766 - val_loss: 2.0172 - val_accuracy: 0.6456
# Epoch 42/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2166 - accuracy: 0.8760 - val_loss: 2.0048 - val_accuracy: 0.6399
# Epoch 43/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2129 - accuracy: 0.8842 - val_loss: 2.0685 - val_accuracy: 0.6422
# Epoch 44/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2137 - accuracy: 0.8804 - val_loss: 2.0954 - val_accuracy: 0.6560
# Epoch 45/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2097 - accuracy: 0.8802 - val_loss: 2.0648 - val_accuracy: 0.6422
# Epoch 46/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2074 - accuracy: 0.8799 - val_loss: 2.1377 - val_accuracy: 0.6445
# Epoch 47/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2030 - accuracy: 0.8827 - val_loss: 2.2122 - val_accuracy: 0.6491
# Epoch 48/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2053 - accuracy: 0.8855 - val_loss: 2.1156 - val_accuracy: 0.6502
# Epoch 49/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2008 - accuracy: 0.8838 - val_loss: 2.1544 - val_accuracy: 0.6468
# Epoch 50/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.1929 - accuracy: 0.8897 - val_loss: 2.1846 - val_accuracy: 0.6479
# Epoch 51/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.1932 - accuracy: 0.8867 - val_loss: 2.2800 - val_accuracy: 0.6445
# Epoch 52/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.1929 - accuracy: 0.8856 - val_loss: 2.2217 - val_accuracy: 0.6319
# Epoch 53/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.1877 - accuracy: 0.8902 - val_loss: 2.3182 - val_accuracy: 0.6456
# Epoch 54/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.1907 - accuracy: 0.8897 - val_loss: 2.2843 - val_accuracy: 0.6433
# Epoch 55/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.1934 - accuracy: 0.8902 - val_loss: 2.3341 - val_accuracy: 0.6365
# Epoch 56/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.1892 - accuracy: 0.8883 - val_loss: 2.2693 - val_accuracy: 0.6548
# Epoch 57/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.1811 - accuracy: 0.8932 - val_loss: 2.2884 - val_accuracy: 0.6479
# Epoch 58/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.1831 - accuracy: 0.8940 - val_loss: 2.4041 - val_accuracy: 0.6571
# Epoch 59/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.1803 - accuracy: 0.8933 - val_loss: 2.4069 - val_accuracy: 0.6537
# Epoch 60/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.1758 - accuracy: 0.8957 - val_loss: 2.4882 - val_accuracy: 0.6525
# Epoch 61/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.1828 - accuracy: 0.8925 - val_loss: 2.4141 - val_accuracy: 0.6468
# Epoch 62/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.1875 - accuracy: 0.8910 - val_loss: 2.3807 - val_accuracy: 0.6560
# Epoch 63/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.1798 - accuracy: 0.8932 - val_loss: 2.4835 - val_accuracy: 0.6388
# Epoch 64/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.1771 - accuracy: 0.8955 - val_loss: 2.4948 - val_accuracy: 0.6433
# Epoch 65/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.1732 - accuracy: 0.8972 - val_loss: 2.5327 - val_accuracy: 0.6376
# Epoch 66/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.1713 - accuracy: 0.8972 - val_loss: 2.5100 - val_accuracy: 0.6388
# Epoch 67/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.1707 - accuracy: 0.8960 - val_loss: 2.5513 - val_accuracy: 0.6433
# Epoch 68/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.1753 - accuracy: 0.8934 - val_loss: 2.5924 - val_accuracy: 0.6433
# Epoch 69/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.1748 - accuracy: 0.8979 - val_loss: 2.6413 - val_accuracy: 0.6468
# Epoch 70/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.1738 - accuracy: 0.9008 - val_loss: 2.5802 - val_accuracy: 0.6330
# Epoch 71/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.1674 - accuracy: 0.8987 - val_loss: 2.6709 - val_accuracy: 0.6468
# Epoch 72/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.1657 - accuracy: 0.9015 - val_loss: 2.6049 - val_accuracy: 0.6376
# Epoch 73/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.1659 - accuracy: 0.9024 - val_loss: 2.6542 - val_accuracy: 0.6307
# Epoch 74/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.1656 - accuracy: 0.9018 - val_loss: 2.7418 - val_accuracy: 0.6411
# Epoch 75/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.1710 - accuracy: 0.8982 - val_loss: 2.6616 - val_accuracy: 0.6239
# Epoch 76/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.1666 - accuracy: 0.9018 - val_loss: 2.6872 - val_accuracy: 0.6399
# Epoch 77/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.1673 - accuracy: 0.9013 - val_loss: 2.6251 - val_accuracy: 0.6388
# Epoch 78/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.1626 - accuracy: 0.9033 - val_loss: 2.7282 - val_accuracy: 0.6411
# Epoch 79/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.1638 - accuracy: 0.9015 - val_loss: 2.7236 - val_accuracy: 0.6342
# Epoch 80/80
# 313/313 [==============================] - 2s 6ms/step - loss: 0.1609 - accuracy: 0.9044 - val_loss: 2.7595 - val_accuracy: 0.6307
# Finish - Creating and Training a model using the Embeding with LSTM layer

# %%
plot_graph(lstm_model_history, 'accuracy')
plot_graph(lstm_model_history, 'loss')

# %%
# - Creating and Training a model using the Embeding with multiple LSTM layer

# -- building the model
lstm_multi_sentiment_model = tf.keras.Sequential([
                                            tf.keras.layers.Embedding(input_dim= vaocab_len, output_dim= embed_dim, input_length= max_len),
                                            tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(embed_dim, return_sequences=True)), 
                                            tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(embed_dim)),
                                            tf.keras.layers.Dense(1, activation='sigmoid')
])

learning_rate = 0.00003 # slower than the default learning rate
# -- compiling the model
# lstm_sentiment_model.compile(loss= "binary_crossentropy", optimizer= tf.keras.optimizers.Adam(learning_rate), metrics=['accuracy'])
lstm_multi_sentiment_model.compile(loss= "binary_crossentropy", optimizer= 'adam', metrics=['accuracy'])
lstm_multi_sentiment_model.summary

# -- trainging the model
lstm_multi_model_history = lstm_multi_sentiment_model.fit(dataset_train_padding, dataset_train_labels_final, epochs= 20, validation_data=(dataset_val_padding, dataset_val_labels_final))

lstm_multi_sentiment_model.save("lstm_multi_sentiment_model.h5")


print("Finish - Creating and Training a model using the Embeding with multiple LSTM layer")
# Out:
# Epoch 1/20
# 313/313 [==============================] - 4s 13ms/step - loss: 0.6285 - accuracy: 0.6324 - val_loss: 0.5835 - val_accuracy: 0.6892
# Epoch 2/20
# 313/313 [==============================] - 3s 10ms/step - loss: 0.5229 - accuracy: 0.7214 - val_loss: 0.5876 - val_accuracy: 0.6961
# Epoch 3/20
# 313/313 [==============================] - 3s 10ms/step - loss: 0.4995 - accuracy: 0.7346 - val_loss: 0.5943 - val_accuracy: 0.6789
# Epoch 4/20
# 313/313 [==============================] - 3s 10ms/step - loss: 0.4817 - accuracy: 0.7458 - val_loss: 0.6127 - val_accuracy: 0.6938
# Epoch 5/20
# 313/313 [==============================] - 3s 10ms/step - loss: 0.4668 - accuracy: 0.7485 - val_loss: 0.6193 - val_accuracy: 0.6869
# Epoch 6/20
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4487 - accuracy: 0.7599 - val_loss: 0.6508 - val_accuracy: 0.6869
# Epoch 7/20
# 313/313 [==============================] - 3s 10ms/step - loss: 0.4294 - accuracy: 0.7677 - val_loss: 0.7000 - val_accuracy: 0.6789
# Epoch 8/20
# 313/313 [==============================] - 3s 10ms/step - loss: 0.4103 - accuracy: 0.7743 - val_loss: 0.7380 - val_accuracy: 0.6800
# Epoch 9/20
# 313/313 [==============================] - 3s 10ms/step - loss: 0.3958 - accuracy: 0.7827 - val_loss: 0.8010 - val_accuracy: 0.6537
# Epoch 10/20
# 313/313 [==============================] - 3s 9ms/step - loss: 0.3784 - accuracy: 0.7886 - val_loss: 0.8648 - val_accuracy: 0.6800
# Epoch 11/20
# 313/313 [==============================] - 3s 9ms/step - loss: 0.3666 - accuracy: 0.7996 - val_loss: 0.9251 - val_accuracy: 0.6732
# Epoch 12/20
# 313/313 [==============================] - 3s 9ms/step - loss: 0.3582 - accuracy: 0.8003 - val_loss: 0.8601 - val_accuracy: 0.6617
# Epoch 13/20
# 313/313 [==============================] - 3s 10ms/step - loss: 0.3512 - accuracy: 0.8073 - val_loss: 0.8879 - val_accuracy: 0.6778
# Epoch 14/20
# 313/313 [==============================] - 3s 9ms/step - loss: 0.3406 - accuracy: 0.8118 - val_loss: 0.9605 - val_accuracy: 0.6525
# Epoch 15/20
# 313/313 [==============================] - 3s 9ms/step - loss: 0.3288 - accuracy: 0.8131 - val_loss: 1.0330 - val_accuracy: 0.6617
# Epoch 16/20
# 313/313 [==============================] - 3s 9ms/step - loss: 0.3174 - accuracy: 0.8208 - val_loss: 1.0481 - val_accuracy: 0.6468
# Epoch 17/20
# 313/313 [==============================] - 3s 9ms/step - loss: 0.3180 - accuracy: 0.8219 - val_loss: 1.1239 - val_accuracy: 0.6709
# Epoch 18/20
# 313/313 [==============================] - 3s 9ms/step - loss: 0.3093 - accuracy: 0.8239 - val_loss: 1.1114 - val_accuracy: 0.6479
# Epoch 19/20
# 313/313 [==============================] - 3s 10ms/step - loss: 0.3025 - accuracy: 0.8304 - val_loss: 1.0798 - val_accuracy: 0.6261
# Epoch 20/20
# 313/313 [==============================] - 3s 9ms/step - loss: 0.2981 - accuracy: 0.8291 - val_loss: 1.2168 - val_accuracy: 0.6617
# Finish - Creating and Training a model using the Embeding with multiple LSTM layer

# %%
plot_graph(lstm_multi_model_history, 'accuracy')
plot_graph(lstm_multi_model_history, 'loss')

# %%
# - defining a generic function for prediction 
def predict_sentiment(model, reviews):
  review_sequence = tokenizer.texts_to_sequences(reviews)
  review_padding = pad_sequences(review_sequence, maxlen = max_len, padding=padding)
  classes = model.predict(review_padding)

  for x in range(len(review_padding)):
    print(reviews[x]," ::", classes[x])

print("Finish - defining a generic function for prediction ")
# Out:
# Finish - defining a generic function for prediction

# %%
# - Predicting the sentiment of few reviews

review1 = """I loved this movie"""

review2 = """that was the worst movie I've ever seen"""

review3 = """too much violence even for a Bond film"""

review4 = """a captivating recounting of a cherished myth"""

review5 = "the audience were just worst though movie was good"

review6 = "last pair of scratched 3d glass was availble and I had to rent for seeing the picture"

new_reviews = [review1, review2, review3, review4, review5, review6]

# -- predicting using the Embeded Layer Model
print("\n==> Predicting using the Embeded Layer Model\n")
predict_sentiment(embed_sentiment_model, new_reviews)

# -- predicting using the Embeded & CNN Layer Model
print("\n==> Predicting using the Embeded & CNN  Layer Model\n")
predict_sentiment(cnn_sentiment_model, new_reviews)

# -- predicting using the Embeded & GRU Layer Model
print("\n==> Predicting using the Embeded & GRU  Layer Model\n")
predict_sentiment(gru_sentiment_model, new_reviews)

# -- predicting using the Embeded & LSTM Layer Model
print("\n==> Predicting using the Embeded & LSTM Layer Model\n")
predict_sentiment(lstm_sentiment_model, new_reviews)

# -- predicting using the Embeded & multi LSTM Layer Model
print("\n==> Predicting using the Embeded & multi LSTM Layer Model\n")
predict_sentiment(lstm_multi_sentiment_model, new_reviews)

print("\n Finish - Predicting the sentiment of few reviews")
# Out:
# ==> Predicting using the Embeded Layer Model
#
# I loved this movie  :: [0.40454742]
# that was the worst movie I've ever seen  :: [0.01409087]
# too much violence even for a Bond film  :: [0.08891091]
# a captivating recounting of a cherished myth  :: [0.4840575]
# the audience were just worst though movie was good  :: [0.00304686]
# last pair of scratched 3d glass was availble and I had to rent for seeing the picture  :: [0.8335595]
#
# ==> Predicting using the Embeded & CNN  Layer Model
#
# I loved this movie  :: [0.24182619]
# that was the worst movie I've ever seen  :: [0.00615974]
# too much violence even for a Bond film  :: [0.06183462]
# a captivating recounting of a cherished myth  :: [0.3856358]
# the audience were just worst though movie was good  :: [0.00071959]
# last pair of scratched 3d glass was availble and I had to rent for seeing the picture  :: [0.6478995]
#
# ==> Predicting using the Embeded & GRU  Layer Model
#
# I loved this movie  :: [0.3793744]
# that was the worst movie I've ever seen  :: [0.1986886]
# too much violence even for a Bond film  :: [0.17293455]
# a captivating recounting of a cherished myth  :: [0.39902598]
# the audience were just worst though movie was good  :: [0.15797795]
# last pair of scratched 3d glass was availble and I had to rent for seeing the picture  :: [0.7432331]
#
# ==> Predicting using the Embeded & LSTM Layer Model
#
# I loved this movie  :: [0.2630816]
# that was the worst movie I've ever seen  :: [0.01516492]
# too much violence even for a Bond film  :: [1.2894839e-07]
# a captivating recounting of a cherished myth  :: [0.38696986]
# the audience were just worst though movie was good  :: [9.974547e-09]
# last pair of scratched 3d glass was availble and I had to rent for seeing the picture  :: [0.81318873]
#
# ==> Predicting using the Embeded & multi LSTM Layer Model
#
# I loved this movie  :: [0.49769467]
# that was the worst movie I've ever seen  :: [0.08275869]
# too much violence even for a Bond film  :: [0.01516135]
# a captivating recounting of a cherished myth  :: [0.5007669]
# the audience were just worst though movie was good  :: [0.07271776]
# last pair of scratched 3d glass was availble and I had to rent for seeing the picture  :: [0.9959502]
#
#  Finish - Predicting the sentiment of few reviews
